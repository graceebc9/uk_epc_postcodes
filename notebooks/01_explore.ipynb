# %%
import pandas as pd

# %%
df = pd.read_csv('/Volumes/T9/2025_01_EPC_POSTCODES/W06000005-Flintshire_results.csv')

# %%
df.fillna(0)
# Out:
#       Unnamed: 0  count_buildings  mean_CURRENT_ENERGY_EFFICIENCY  postcode  \
# 0              0               22                           60.36   CH5 2AB
# 1              1               15                           62.40   CH7 2AW
# 2              2                4                           56.50   CH8 7NG
# 3              3               22                           41.32   CH8 8SU
# 4              4               22                           64.86   CH7 4AB
# ...          ...              ...                             ...       ...
# 4084        4084                2                           37.00  LL12 9RN
# 4085        4085                2                           68.50   CH8 8HS
# 4086        4086                3                           90.00   CH7 6GZ
# 4087        4087                6                           75.17   CH5 2GX
# 4088        4088                9                           88.78   CH7 2DS
#
# ...

# %%
df
# Out:
#       Unnamed: 0  count_buildings  mean_CURRENT_ENERGY_EFFICIENCY  postcode  \
# 0              0               22                           60.36   CH5 2AB
# 1              1               15                           62.40   CH7 2AW
# 2              2                4                           56.50   CH8 7NG
# 3              3               22                           41.32   CH8 8SU
# 4              4               22                           64.86   CH7 4AB
# ...          ...              ...                             ...       ...
# 4084        4084                2                           37.00  LL12 9RN
# 4085        4085                2                           68.50   CH8 8HS
# 4086        4086                3                           90.00   CH7 6GZ
# 4087        4087                6                           75.17   CH5 2GX
# 4088        4088                9                           88.78   CH7 2DS
#
# ...

# %%
df.shape
# Out:
# (4089, 30)

# %%
cv = pd.read_csv('/Volumes/T9/2024_Data_downloads/2025_epc_database/all-domestic-certificates/domestic-W06000005-Flintshire/certificates.csv')
# Out:
# /Users/gracecolverd/opt/miniconda3/envs/ads4/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (34,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cv['CURRENT_ENERGY_EFFICIENCY'].mean()
# Out:
# 62.97263470852448

# %%
cv.POTENTIAL_ENERGY_EFFICIENCY.mean()
# Out:
# 80.35395853646841

# %%
cv[cv['POSTCODE']=='CH7 2DS'][['CURRENT_ENERGY_EFFICIENCY', 'POTENTIAL_ENERGY_EFFICIENCY']].mean()
# Out:
# CURRENT_ENERGY_EFFICIENCY      88.777778
# POTENTIAL_ENERGY_EFFICIENCY    88.777778
# dtype: float64

# %%
cv[cv['POSTCODE']=='CH7 2DS']
# Out:
#                                                  LMK_KEY      ADDRESS1  \
# 62270  1f34c04bae37119f29961289475141e82bb1580ec2e6bd...  2, Llys Alun
# 62274  20c013d8280db21f8037d49a62f64d8244f827531f3292...  8, Llys Alun
# 62308  3cc3e64b8bf03b9bd3617631934138529e040a95e881bd...  4, Llys Alun
# 62405  89f62f2a32687e93b8dc0e7050ae4c06f909f8e7f72b3b...  7, Llys Alun
# 62429  98e7451cb540a0262a9aea4cba9235c7269f2276f5af05...  3, Llys Alun
# 62454  af407128390aeb0845d43cdb58a2a233bdd96d2d702c9f...  5, Llys Alun
# 62488  c9eb1ce016f287a7c45e6d14a89dba0196af1da0fdc29d...  9, Llys Alun
# 62497  d18d86004dce53633e63d9777a1d5017b528475862f27a...  6, Llys Alun
# 62517  e52fc1fd52fd04fec96a2af2b7e2a389d2497182db7c09...  1, Llys Alun
#
#            ADDRESS2 ADDRESS3 POSTCODE  BUILDING_REFERENCE_NUMBER  \
# 62270  Brunswick Rd      NaN  CH7 2DS                10006666209
# 62274  Brunswick Rd      NaN  CH7 2DS                10006729526
# ...

# %%
cv.columns.tolist()
# Out:
# ['LMK_KEY',
#  'ADDRESS1',
#  'ADDRESS2',
#  'ADDRESS3',
#  'POSTCODE',
#  'BUILDING_REFERENCE_NUMBER',
#  'CURRENT_ENERGY_RATING',
#  'POTENTIAL_ENERGY_RATING',
#  'CURRENT_ENERGY_EFFICIENCY',
#  'POTENTIAL_ENERGY_EFFICIENCY',
#  'PROPERTY_TYPE',
#  'BUILT_FORM',
#  'INSPECTION_DATE',
#  'LOCAL_AUTHORITY',
#  'CONSTITUENCY',
#  'COUNTY',
#  'LODGEMENT_DATE',
#  'TRANSACTION_TYPE',
#  'ENVIRONMENT_IMPACT_CURRENT',
#  'ENVIRONMENT_IMPACT_POTENTIAL',
#  'ENERGY_CONSUMPTION_CURRENT',
#  'ENERGY_CONSUMPTION_POTENTIAL',
#  'CO2_EMISSIONS_CURRENT',
#  'CO2_EMISS_CURR_PER_FLOOR_AREA',
#  'CO2_EMISSIONS_POTENTIAL',
#  'LIGHTING_COST_CURRENT',
#  'LIGHTING_COST_POTENTIAL',
#  'HEATING_COST_CURRENT',
#  'HEATING_COST_POTENTIAL',
#  'HOT_WATER_COST_CURRENT',
#  'HOT_WATER_COST_POTENTIAL',
#  'TOTAL_FLOOR_AREA',
#  'ENERGY_TARIFF',
#  'MAINS_GAS_FLAG',
#  'FLOOR_LEVEL',
#  'FLAT_TOP_STOREY',
#  'FLAT_STOREY_COUNT',
#  'MAIN_HEATING_CONTROLS',
#  'MULTI_GLAZE_PROPORTION',
#  'GLAZED_TYPE',
# ...

# %%
cv[['LODGEMENT_DATE', 'INSPECTION_DATE' ]]
# Out:
#       LODGEMENT_DATE INSPECTION_DATE
# 0         2008-11-06      2008-11-05
# 1         2012-11-28      2012-11-28
# 2         2010-04-27      2010-04-27
# 3         2010-03-02      2010-03-02
# 4         2009-03-06      2009-03-06
# ...              ...             ...
# 62556     2024-10-28      2024-10-26
# 62557     2024-10-16      2024-10-15
# 62558     2024-10-28      2024-10-25
# 62559     2024-10-03      2024-10-01
# 62560     2024-08-08      2024-08-07
#
# [62561 rows x 2 columns]

# %%
cv.groupby('UPRN').count()
# Out:
#               LMK_KEY  ADDRESS1  ADDRESS2  ADDRESS3  POSTCODE  \
# UPRN
# 1.001355e+10        2         2         2         0         2
# 1.001369e+10        2         2         0         0         2
# 1.001369e+10        1         1         1         0         1
# 1.001369e+10        1         1         1         0         1
# 1.001369e+10        2         2         2         0         2
# ...               ...       ...       ...       ...       ...
# 2.000043e+11        2         2         2         0         2
# 2.000043e+11        1         1         1         0         1
# 2.000043e+11        1         1         1         0         1
# 2.000043e+11        2         2         2         0         2
# 2.000043e+11        1         1         1         1         1
#
#               BUILDING_REFERENCE_NUMBER  CURRENT_ENERGY_RATING  \
# UPRN
# 1.001355e+10                          2                      2
# 1.001369e+10                          2                      2
# ...

# %%
# Assuming your dataframe is named 'df'
latest_entries = cv.sort_values('INSPECTION_DATE').groupby('UPRN').last().reset_index()

# %%
latest_entries.shape, cv.shape
# Out:
# ((45243, 92), (62561, 92))
